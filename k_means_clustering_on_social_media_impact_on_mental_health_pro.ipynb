# %% [markdown]
# importing libraries

# %% [markdown]
# Pandas for data manipulation and analysis.Numpy for numerical computing.Matplotlib.pyplot,Pyplot creates visualizations.Seaborn creates statistically informative and visually appealing plots.import warnings,used to manage warning messages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading the dataset

# %% [markdown]
# Involves reading data from the file and stores it in a Pandas DataFrame named data.The head() function displays the first few rows of the DataFrame.

# %%
data= pd.read_csv("/content/smmh.csv")
data.head()
# Out:
#    Unnamed: 0           timestamp   age  gender relationship_status  \
# 0           0  4/18/2022 19:18:47  21.0    Male   In a relationship
# 1           1  4/18/2022 19:19:28  21.0  Female              Single
# 2           2  4/18/2022 19:25:59  21.0  Female              Single
# 3           3  4/18/2022 19:29:43  21.0  Female              Single
# 4           4  4/18/2022 19:33:31  21.0  Female              Single
#
#     occupation_status affiliated_organizations use_social_media  \
# 0  University Student               University              Yes
# 1  University Student               University              Yes
# 2  University Student               University              Yes
# 3  University Student               University              Yes
# 4  University Student               University              Yes
#
#                               social_media_platforms daily_social_media_time  \
# 0  Facebook, Twitter, Instagram, YouTube, Discord...   Between 2 and 3 hours
# ...

# %% [markdown]
# Displays the dimensions of the dataset which has 481 rows and 23 columns

# %%
data.shape
# Out:
# (481, 23)

# %% [markdown]
# The dataset has 11063 datapoints or the cells.
#
# ```
# # This is formatted as code
# ```

# %%
data.size
# Out:
# 11063

# %% [markdown]
# info() function gives a summary of dataframe,structure,datatypes and memory usage

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          481 non-null    int64
#  1   timestamp                           481 non-null    object
#  2   age                                 481 non-null    float64
#  3   gender                              481 non-null    object
#  4   relationship_status                 481 non-null    object
#  5   occupation_status                   481 non-null    object
#  6   affiliated_organizations            481 non-null    object
#  7   use_social_media                    481 non-null    object
#  8   social_media_platforms              481 non-null    object
#  9   daily_social_media_time             481 non-null    object
#  10  frequency_social_media_no_purpose   481 non-null    int64
# ...

# %% [markdown]
# displays the data type of each column within the pandas dataframe named data

# %%
data.dtypes
# Out:
# Unnamed: 0                              int64
# timestamp                              object
# age                                   float64
# gender                                 object
# relationship_status                    object
# occupation_status                      object
# affiliated_organizations               object
# use_social_media                       object
# social_media_platforms                 object
# daily_social_media_time                object
# frequency_social_media_no_purpose       int64
# frequency_social_media_distracted       int64
# restless_without_social_media           int64
# distractibility_scale                   int64
# worry_level_scale                       int64
# difficulty_concentrating                int64
# compare_to_successful_people_scale      int64
# feelings_about_comparisons              int64
# frequency_seeking_validation            int64
# frequency_feeling_depressed             int64
# ...

# %% [markdown]
# the column retrieves the names of all columns present in the dataframe

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'timestamp', 'age', 'gender', 'relationship_status',
#        'occupation_status', 'affiliated_organizations', 'use_social_media',
#        'social_media_platforms', 'daily_social_media_time',
#        'frequency_social_media_no_purpose',
#        'frequency_social_media_distracted', 'restless_without_social_media',
#        'distractibility_scale', 'worry_level_scale',
#        'difficulty_concentrating', 'compare_to_successful_people_scale',
#        'feelings_about_comparisons', 'frequency_seeking_validation',
#        'frequency_feeling_depressed', 'interest_fluctuation_scale',
#        'sleep_issues_scale', 'Cluster'],
#       dtype='object')

# %% [markdown]
# creating a dictionary called new_column_names that converts initial column names to shorter.Then using rename() function to apply these changes to the data DataFrame,improving readability and usability.

# %%
new_column_names = {
    'Timestamp': 'timestamp',
    '1. What is your age?': 'age',
    '2. Gender': 'gender',
    '3. Relationship Status': 'relationship_status',
    '4. Occupation Status': 'occupation_status',
    '5. What type of organizations are you affiliated with?': 'affiliated_organizations',
    '6. Do you use social media?': 'use_social_media',
    '7. What social media platforms do you commonly use?': 'social_media_platforms',
    '8. What is the average time you spend on social media every day?': 'daily_social_media_time',
    '9. How often do you find yourself using Social media without a specific purpose?': 'frequency_social_media_no_purpose',
    '10. How often do you get distracted by Social media when you are busy doing something?': 'frequency_social_media_distracted',
    "11. Do you feel restless if you haven't used Social media in a while?": 'restless_without_social_media',
    '12. On a scale of 1 to 5, how easily distracted are you?': 'distractibility_scale',
    '13. On a scale of 1 to 5, how much are you bothered by worries?': 'worry_level_scale',
    '14. Do you find it difficult to concentrate on things?': 'difficulty_concentrating',
    '15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?': 'compare_to_successful_people_scale',
    '16. Following the previous question, how do you feel about these comparisons, generally speaking?': 'feelings_about_comparisons',
    '17. How often do you look to seek validation from features of social media?': 'frequency_seeking_validation',
    '18. How often do you feel depressed or down?': 'frequency_feeling_depressed',
    '19. On a scale of 1 to 5, how frequently does your interest in daily activities fluctuate?': 'interest_fluctuation_scale',
    '20. On a scale of 1 to 5, how often do you face issues regarding sleep?': 'sleep_issues_scale',
}
data= data.rename(columns=new_column_names)

# %% [markdown]
# creating a backup of the DataFrame data using function copy for safing modifications and then displays its structure and information.

# %%
data_copy =data.copy()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          481 non-null    int64
#  1   timestamp                           481 non-null    object
#  2   age                                 481 non-null    float64
#  3   gender                              481 non-null    object
#  4   relationship_status                 481 non-null    object
#  5   occupation_status                   481 non-null    object
#  6   affiliated_organizations            481 non-null    object
#  7   use_social_media                    481 non-null    object
#  8   social_media_platforms              481 non-null    object
#  9   daily_social_media_time             481 non-null    object
#  10  frequency_social_media_no_purpose   481 non-null    int64
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                            0
# timestamp                             0
# age                                   0
# gender                                0
# relationship_status                   0
# occupation_status                     0
# affiliated_organizations              0
# use_social_media                      0
# social_media_platforms                0
# daily_social_media_time               0
# frequency_social_media_no_purpose     0
# frequency_social_media_distracted     0
# restless_without_social_media         0
# distractibility_scale                 0
# worry_level_scale                     0
# difficulty_concentrating              0
# compare_to_successful_people_scale    0
# feelings_about_comparisons            0
# frequency_seeking_validation          0
# frequency_feeling_depressed           0
# interest_fluctuation_scale            0
# sleep_issues_scale                    0
# Cluster                               0
# dtype: int64

# %%
mode_value=data['affiliated_organizations'].mode()[0]
data['affiliated_organizations'].fillna(mode_value, inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                            0
# timestamp                             0
# age                                   0
# gender                                0
# relationship_status                   0
# occupation_status                     0
# affiliated_organizations              0
# use_social_media                      0
# social_media_platforms                0
# daily_social_media_time               0
# frequency_social_media_no_purpose     0
# frequency_social_media_distracted     0
# restless_without_social_media         0
# distractibility_scale                 0
# worry_level_scale                     0
# difficulty_concentrating              0
# compare_to_successful_people_scale    0
# feelings_about_comparisons            0
# frequency_seeking_validation          0
# frequency_feeling_depressed           0
# interest_fluctuation_scale            0
# sleep_issues_scale                    0
# Cluster                               0
# dtype: int64

# %%
duplicate_rows =data[data.duplicated()]
duplicate_rows.sum()
# Out:
# Unnamed: 0                              0
# timestamp                               0
# age                                   0.0
# gender                                  0
# relationship_status                     0
# occupation_status                       0
# affiliated_organizations                0
# use_social_media                        0
# social_media_platforms                  0
# daily_social_media_time                 0
# frequency_social_media_no_purpose       0
# frequency_social_media_distracted       0
# restless_without_social_media           0
# distractibility_scale                   0
# worry_level_scale                       0
# difficulty_concentrating                0
# compare_to_successful_people_scale      0
# feelings_about_comparisons              0
# frequency_seeking_validation            0
# frequency_feeling_depressed             0
# interest_fluctuation_scale              0
# sleep_issues_scale                      0
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'timestamp', 'age', 'gender', 'relationship_status',
#        'occupation_status', 'affiliated_organizations', 'use_social_media',
#        'social_media_platforms', 'daily_social_media_time',
#        'frequency_social_media_no_purpose',
#        'frequency_social_media_distracted', 'restless_without_social_media',
#        'distractibility_scale', 'worry_level_scale',
#        'difficulty_concentrating', 'compare_to_successful_people_scale',
#        'feelings_about_comparisons', 'frequency_seeking_validation',
#        'frequency_feeling_depressed', 'interest_fluctuation_scale',
#        'sleep_issues_scale', 'Cluster'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Unnamed: 0        age  frequency_social_media_no_purpose  \
# count  481.000000  481.00000                         481.000000
# mean   240.000000   26.13659                           3.553015
# std    138.997002    9.91511                           1.096299
# min      0.000000   13.00000                           1.000000
# 25%    120.000000   21.00000                           3.000000
# 50%    240.000000   22.00000                           4.000000
# 75%    360.000000   26.00000                           4.000000
# max    480.000000   91.00000                           5.000000
#
#        frequency_social_media_distracted  restless_without_social_media  \
# count                         481.000000                     481.000000
# mean                            3.320166                       2.588358
# std                             1.328137                       1.257059
# min                             1.000000                       1.000000
# ...

# %%
average_age=data['age'].mean()
plt.figure(figsize=(10, 6))
plt.hist(data['age'], bins=20, edgecolor='k')
plt.title('Age Distribution of Survey Respondents')
plt.xlabel('Age')
plt.ylabel('Number of Respondents')
plt.show()

# %% [markdown]
# INSIGHTS:A LOT OF RESPONDENTS LIE IN THE AGE  OF 20-30

# %%
gender_distribution =data['gender'].value_counts()
plt.figure(figsize=(8, 6))
gender_distribution.plot(kind='bar')
plt.title('Gender Distribution of Survey Respondents')
plt.xlabel('Gender')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=60)
plt.show()

# %%
relationship_statuses =data['relationship_status'].value_counts()
plt.figure(figsize=(10, 6))
relationship_statuses.plot(kind='bar')
plt.title('Relationship Status of Survey Respondents')
plt.xlabel('Relationship Status')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=45)
plt.show()

# %%
occupation_statuses =data['occupation_status'].value_counts()
plt.figure(figsize=(10, 6))
occupation_statuses.plot(kind='bar')
plt.title('Occupation Status of Survey Respondents')
plt.xlabel('Occupation Status')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=45)
plt.show()

# %%
social_media_platforms =data['social_media_platforms'].str.split(', ', expand=True).stack().value_counts()
plt.figure(figsize=(10, 6))
social_media_platforms.plot(kind='bar')
plt.title('Commonly Used Social Media Platforms by Respondents')
plt.xlabel('Social Media Platform')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=45)
plt.show()

# %%
daily_usage_distribution = data['daily_social_media_time'].value_counts()
plt.figure(figsize=(10, 6))
daily_usage_distribution.plot(kind='bar')
plt.title('Distribution of Daily Social Media Usage Times')
plt.xlabel('Daily Usage Time')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='gender', y='distractibility_scale', data=data)
plt.title('Gender-Based Differences in Distractibility')
plt.xlabel('Gender')
plt.ylabel('Distractibility Scale')
plt.show()
plt.figure(figsize=(10, 6))
sns.boxplot(x='gender', y='worry_level_scale', data=data)
plt.title('Gender-Based Differences in Worry Levels')
plt.xlabel('Gender')
plt.ylabel('Worry Level Scale')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='frequency_social_media_distracted', data=data)
plt.title('Relationship Between Age and Frequency of Distraction by Social Media')
plt.xlabel('Age')
plt.ylabel('Frequency of Distraction by Social Media')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='affiliated_organizations', y='frequency_seeking_validation', data=data)
plt.title('Affiliated Organizations and Frequency of Seeking Validation from Social Media')
plt.xlabel('Affiliated Organizations')
plt.ylabel('Frequency of Seeking Validation')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(30,45))
num_numeric_cols = sum(data[col].dtype != 'object' for col in data.columns)
num_rows = (num_numeric_cols + 1)
for i,col in enumerate(data.columns):
  if data[col].dtype !='object':
    ax = plt.subplot(num_rows,2,i+1)
    sns.kdeplot(data[col],ax=ax)
    plt.xlabel(col)
    plt.show()

# %%
plt.figure(figsize=(10,60))
for i in range(0,17):
  # Skip the first column ('timestamp') which is not numerical
  if i == 0:
    continue

  # Check if the column is numeric
  if data[data.columns[i]].dtype != 'object':
    plt.subplot(17,1,i+1)
    sns.distplot(data[data.columns[i]],kde_kws={'color':"b",'bw':0.1,'lw':3,"label":"KDE"},hist_kws={"color":"g"})
    plt.title(data.columns[i])
    plt.tight_layout()

# %%
# Select only numeric columns for correlation calculation
numeric_data = data.select_dtypes(include=np.number)
# Calculate correlation for numeric columns
plt.figure(figsize=(12, 12))
sns.heatmap(numeric_data.corr(), annot=True)
plt.show()

# %%
#FEATURE SCALING
from sklearn.preprocessing import StandardScaler # Import StandardScaler
scalar=StandardScaler()
# Select only numeric features for scaling
numeric_features = data.select_dtypes(include=np.number)
# Fit and transform on numeric features only
scaled_data = scalar.fit_transform(numeric_features)

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
principal_components = pca.fit_transform(scaled_data)
pca_data = pd.DataFrame(data=principal_components,columns=["PCA1","PCA2"])
pca_data
# Out:
#          PCA1      PCA2
# 0    1.360909 -0.066113
# 1    1.620197 -0.252252
# 2   -0.456171 -1.778722
# 3   -0.006483 -0.893190
# 4    1.791497  0.890895
# ..        ...       ...
# 476  1.102505  0.504053
# 477 -0.155699 -0.573247
# 478 -0.788224  0.142622
# 479  0.043599 -1.073929
# 480 -3.471525  1.862617
#
# [481 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
# Create the histogram
plt.hist(pca_data['PCA1'], bins=10)
# Customizing the plot
plt.xlabel('PCA1 Values')
plt.ylabel('Frequency')
plt.title('Histogram of PCA1')
# Showing the plot
plt.show()

# %%
import matplotlib.pyplot as plt
# Creating the histogram
plt.hist(pca_data['PCA2'], bins=10)
# Customizing the plot
plt.xlabel('PCA2 Values')
plt.ylabel('Frequency')
plt.title('Histogram of PCA2')
# Showing the plot
plt.show()

# %%
#Finding "k value by elbow method"
#Finding "k value by elbow method"
from sklearn.cluster import KMeans # Import the KMeans class
inertia = []
range_val = range(1,15)
for i in range_val:
  kmean = KMeans(n_clusters=i)
  kmean.fit_predict(pd.DataFrame(scaled_data))
  inertia.append(kmean.inertia_)

for i, inertia_value in zip(range_val, inertia):
  plt.plot(i, inertia_value, 'bx-')
plt.xlabel("Values of K")
plt.ylabel("Inertia")
plt.title('The Elbow Method using Inertia')
plt.show()

# %%
kmeans_model=KMeans(3)
kmeans_model.fit_predict(scaled_data)
pca_data_kmeans= pd.concat([pca_data,pd.DataFrame({'cluster':kmeans_model.labels_})],axis=1)

# %%
plt.figure(figsize=(8,8))
ax = sns.scatterplot(x="PCA1",y="PCA2",hue="cluster",data=pca_data_kmeans,palette=['red','green','blue','black'])
plt.title("Clustering using K-Means Algorithm")
plt.show()

# %%
# find all cluster centers
# The original data DataFrame has 21 columns, but have scaled_data only to 13 numeric columns
# cluster_centers = pd.DataFrame(data=kmeans_model.cluster_centers_,columns=[data.columns])  # Incorrect - data.columns has 21 columns
# use the columns from the numeric features used for scaling
cluster_centers = pd.DataFrame(data=kmeans_model.cluster_centers_, columns=numeric_features.columns)

#inverse transform the data
cluster_centers = scalar.inverse_transform(cluster_centers)
cluster_centers = pd.DataFrame(data=cluster_centers, columns=numeric_features.columns) # Use numeric_features.columns here as well
cluster_centers
# Out:
#    Unnamed: 0        age  frequency_social_media_no_purpose  \
# 0  239.283582  23.641791                           3.412935
# 1  221.728261  36.739130                           2.728261
# 2  249.707447  23.615426                           4.106383
#
#    frequency_social_media_distracted  restless_without_social_media  \
# 0                           3.139303                       2.243781
# 1                           1.836957                       1.543478
# 2                           4.239362                       3.468085
#
#    distractibility_scale  worry_level_scale  difficulty_concentrating  \
# 0               3.144279           3.507463                  3.059701
# 1               2.065217           2.032609                  1.608696
# 2               4.196809           4.361702                  4.244681
#
#    compare_to_successful_people_scale  feelings_about_comparisons  \
# 0                            2.467662                    2.915423
# ...

# %%
#CREATING A TARGET COLUMN "CLUSTER" FOR STORING THE CLUSTER SEGMENT
cluster_data = pd.concat([data,pd.DataFrame({'Cluster':kmeans_model.labels_})],axis=1)
cluster_data
# Out:
#      Unnamed: 0           timestamp   age  gender relationship_status  \
# 0             0  4/18/2022 19:18:47  21.0    Male   In a relationship
# 1             1  4/18/2022 19:19:28  21.0  Female              Single
# 2             2  4/18/2022 19:25:59  21.0  Female              Single
# 3             3  4/18/2022 19:29:43  21.0  Female              Single
# 4             4  4/18/2022 19:33:31  21.0  Female              Single
# ..          ...                 ...   ...     ...                 ...
# 476         476  5/21/2022 23:38:28  24.0    Male              Single
# 477         477   5/22/2022 0:01:05  26.0  Female             Married
# 478         478  5/22/2022 10:29:21  29.0  Female             Married
# 479         479  7/14/2022 19:33:47  21.0    Male              Single
# 480         480    11/12/2022 13:16  53.0    Male             Married
#
#       occupation_status affiliated_organizations use_social_media  \
# ...

# %%
# Remove duplicate columns if any
cluster_data = cluster_data.loc[:,~cluster_data.columns.duplicated()]
# Filter cluster_data for cluster 1
cluster_1_data = cluster_data[cluster_data["Cluster"]==0]

# %%
cluster_2_data = cluster_data[cluster_data["Cluster"]==1]
cluster_2_data
# Out:
#      Unnamed: 0           timestamp   age  gender relationship_status  \
# 0             0  4/18/2022 19:18:47  21.0    Male   In a relationship
# 1             1  4/18/2022 19:19:28  21.0  Female              Single
# 4             4  4/18/2022 19:33:31  21.0  Female              Single
# 6             6  4/18/2022 19:36:12  21.0  Female             Married
# 10           10  4/18/2022 19:44:06  24.0    Male              Single
# ..          ...                 ...   ...     ...                 ...
# 448         448  5/13/2022 16:26:54  21.0    Male              Single
# 462         462  5/14/2022 11:26:56  28.0  Female             Married
# 473         473   5/18/2022 2:12:59  26.0  Female             Married
# 475         475  5/21/2022 22:33:02  32.0  Female             Married
# 476         476  5/21/2022 23:38:28  24.0    Male              Single
#
#       occupation_status affiliated_organizations use_social_media  \
# ...

# %%
cluster_3_data = cluster_data[cluster_data["Cluster"]==2]
cluster_3_data
# Out:
#      Unnamed: 0           timestamp   age  gender relationship_status  \
# 9             9  4/18/2022 19:41:34  20.0    Male              Single
# 40           40  4/18/2022 21:32:37  21.0  Female              Single
# 42           42  4/18/2022 21:48:07  56.0  Female             Married
# 46           46  4/18/2022 21:55:35  65.0    Male             Married
# 48           48  4/18/2022 22:04:59  40.0    Male             Married
# ..          ...                 ...   ...     ...                 ...
# 460         460   5/14/2022 7:11:35  50.0    Male             Married
# 467         467  5/14/2022 16:16:32  18.0    Male              Single
# 469         469  5/14/2022 17:33:57  15.0    Male              Single
# 472         472  5/17/2022 17:12:19  35.0  Female             Married
# 480         480    11/12/2022 13:16  53.0    Male             Married
#
#       occupation_status affiliated_organizations use_social_media  \
# ...

# %%
#VIZUALIZATION
sns.countplot(x='Cluster',data=cluster_data)
# Out:
# <Axes: xlabel='Cluster', ylabel='count'>

# %%
for c in cluster_data.drop(['Cluster'],axis=1):
  grid = sns.FacetGrid(cluster_data,col="Cluster")
  grid = grid.map(plt.hist,c)
  plt.show()

# %%
#saving scikitlearn models
import joblib
joblib.dump(kmeans_model,"kmeans_model.pk1")
# Out:
# ['kmeans_model.pk1']

# %%
cluster_data.to_csv("/content/smmh.csv")

# %%
#SPLITTING THE DATASET
from sklearn.model_selection import train_test_split # Import train_test_split
X = cluster_data.drop(['Cluster'],axis=1)
y= cluster_data[["Cluster"]]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3) # Now you can use train_test_split

# %%
X_train
# Out:
#      Unnamed: 0           timestamp   age  gender relationship_status  \
# 155         155   4/20/2022 0:07:24  21.0  Female   In a relationship
# 107         107  4/19/2022 20:13:21  48.0  Female             Married
# 200         200   4/21/2022 0:36:13  21.0  Female              Single
# 51           51  4/18/2022 22:20:42  24.0    Male              Single
# 260         260    05/11/2022 20:12  36.0  Female             Married
# ..          ...                 ...   ...     ...                 ...
# 14           14  4/18/2022 19:59:08  22.0    Male              Single
# 426         426    05/12/2022 21:53  24.0  Female             Married
# 445         445  5/13/2022 11:12:46  23.0    Male              Single
# 50           50  4/18/2022 22:11:57  22.0  Female              Single
# 447         447  5/13/2022 14:28:58  20.0  Female   In a relationship
#
#       occupation_status      affiliated_organizations use_social_media  \
# ...

# %%
X_test
# Out:
#      Unnamed: 0           timestamp   age  gender relationship_status  \
# 1             1  4/18/2022 19:19:28  21.0  Female              Single
# 5             5  4/18/2022 19:33:48  22.0  Female              Single
# 198         198  4/20/2022 23:45:22  17.0    Male              Single
# 129         129  4/19/2022 21:48:13  16.0    Male              Single
# 11           11  4/18/2022 19:44:10  21.0  Female              Single
# ..          ...                 ...   ...     ...                 ...
# 456         456  5/13/2022 22:43:21  56.0    Male             Married
# 477         477   5/22/2022 0:01:05  26.0  Female             Married
# 465         465  5/14/2022 12:12:16  13.0    Male              Single
# 65           65  4/18/2022 23:38:02  24.0    Male   In a relationship
# 405         405    05/12/2022 18:58  19.0  Female              Single
#
#       occupation_status affiliated_organizations use_social_media  \
# ...

# %%
# Assuming 'cluster_data' is your DataFrame
X = cluster_data.drop(['Cluster', 'timestamp'], axis=1)  # Drop 'Cluster' and 'timestamp' columns
y = cluster_data[['Cluster']]

# One-hot encode categorical features
X = pd.get_dummies(X,
                  columns=['gender', 'relationship_status', 'occupation_status',
                           'affiliated_organizations', 'use_social_media',
                           'social_media_platforms', 'daily_social_media_time',
                           'frequency_social_media_no_purpose', 'frequency_social_media_distracted',
                           'restless_without_social_media', 'difficulty_concentrating',
                           'feelings_about_comparisons', 'frequency_seeking_validation',
                           'frequency_feeling_depressed'],
                  drop_first=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
#DECISION TREE
from sklearn.tree import DecisionTreeClassifier  # Import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion="entropy")
model.fit(X_train,y_train)  # Now X_train should only contain numeric features
y_pred = model.predict(X_test)

# %%
#confusion matrix
from sklearn.metrics import classification_report # Import the classification_report function
from sklearn import metrics
print(metrics.confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[46 10  5]
#  [13 41  2]
#  [11  0 17]]
#               precision    recall  f1-score   support
#
#            0       0.66      0.75      0.70        61
#            1       0.80      0.73      0.77        56
#            2       0.71      0.61      0.65        28
#
#     accuracy                           0.72       145
#    macro avg       0.72      0.70      0.71       145
# weighted avg       0.72      0.72      0.72       145

# %%
import pickle
filename = 'final_model.sav'
pickle.dump(model,open(filename,'wb'))
result = model.score(X_test,y_test)
print(result,'%Accuracy')
# Out:
# 0.7172413793103448 %Accuracy

# %%
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.impute import SimpleImputer
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from scipy.spatial import distance

# %%
class DBScanner:

    def __init__(self, config):
        self.eps = config['eps']
        self.min_pts = config['min_pts']
        self.dim = config['dim']
        self.clusters = set()
        self.cluster_count = 0
        self.visited = []
        self.color = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w']

    def dbscan(self, data):
        self.init_params()
        self.data = data

        ## Setting up the plot
        fig = plt.figure()

        axis_proj = 'rectilinear'
        if self.dim > 2:
            axis_proj = '%dd' % self.dim

        ax = fig.add_subplot(111, projection = axis_proj)

        #default noise cluster
        noise = Cluster('Noise', self.dim)
        self.clusters.add(noise)

        for point in data:
            if point not in self.visited:
                self.visited.append(point)
                neighbour_pts = self.region_query(point)
                if len(neighbour_pts) < self.min_pts:
                    noise.add_point(point)
                else:
                    name = 'cluster-%d' % self.cluster_count
                    new_cluster = Cluster(name, self.dim)

                    self.cluster_count += 1
                    self.expand_cluster(new_cluster, point, neighbour_pts)

                    if self.dim == 2:
                        ax.scatter(new_cluster.get_X(), new_cluster.get_Y(), c = self.color[self.cluster_count % len(self.color)],
                        marker = 'o', label = name)
                    elif self.dim == 3:
                        ax.scatter(new_cluster.get_X(), new_cluster.get_Y(), new_cluster.get_Z(), marker = 'o',
                        c = self.color[self.cluster_count % len(self.color)], label = name)

                    ax.hold(True)

        if len(noise.get_points()) != 0:
            if self.dim > 2:
                ax.scatter(noise.get_X(), noise.get_Y(), noise.get_Z(), marker = 'x', label = noise.name)
            else:
                ax.scatter(noise.get_X(), noise.get_Y(), marker = 'x', label = noise.name)

        print ("Number of clusters found: %d" % self.cluster_count)

        ax.hold(False)
        ax.legend(loc='lower left')
        ax.grid(True)
        plt.title(r'DBSCAN Clustering', fontsize=18)
        plt.show()


    def expand_cluster(self, cluster, point, neighbour_pts):
        cluster.add_point(point)
        for p in neighbour_pts:
            if p not in self.visited:
                self.visited.append(p)
                np = self.region_query(p)
                if len(np) >= self.min_pts:
                    for n in np:
                        if n not in neighbour_pts:
                            neighbour_pts.append(n)

                for other_cluster in self.clusters:
                    if not other_cluster.has(p):
                        if not cluster.has(p):
                            cluster.add_point(p)

                if self.cluster_count == 0:
                    if not cluster.has(p):
                        cluster.add_point(p)

        self.clusters.add(cluster)


    def get_distance(self, from_point, to_point):
        p1 = [from_point['value'][k] for k in range(self.dim)]
        p2 = [to_point['value'][k] for k in range(self.dim)]
        return distance.euclidean(p1, p2)


    def region_query(self, point):
        result = []
        for d_point in self.data:
            if d_point != point:
                if self.get_distance(d_point, point) <= self.eps:
                    result.append(d_point)
        return result


    def export(self, export_file="cluster_dump"):
        with open(export_file, 'w') as dump_file:
            for cluster in self.clusters:
                for point in cluster.points:
                    csv_point = ','.join(map(str, point['value']))
                    dump_file.write("%s;%s\n" % (csv_point, cluster.name))
        print ("Cluster dumped at: %s" % export_file)




    def init_params(self):
        self.clusters = set()
        self.cluster_count = 0
        self.visited = []
sns.countplot(x='Cluster', data=cluster_data)
plt.title('Cluster Distribution (DBSCAN)')
plt.show()

# %%
data= pd.DataFrame(X, columns=['PCA1', 'PCA2'])

# %%
X_train, X_test = train_test_split(data, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Assuming 'cluster_data' is your DataFrame
X = cluster_data.drop(['Cluster', 'timestamp'], axis=1)  # Drop 'Cluster' and 'timestamp' columns
y = cluster_data[['Cluster']]

# One-hot encode categorical features
X = pd.get_dummies(X,
                  columns=['gender', 'relationship_status', 'occupation_status',
                           'affiliated_organizations', 'use_social_media',
                           'social_media_platforms', 'daily_social_media_time',
                           'frequency_social_media_no_purpose', 'frequency_social_media_distracted',
                           'restless_without_social_media', 'difficulty_concentrating',
                           'feelings_about_comparisons', 'frequency_seeking_validation',
                           'frequency_feeling_depressed'],
                  drop_first=True,
                  dummy_na=False)  # Adding dummy_na=False to prevent NaN columns

# Checking and handling columns with all zeros or NaNs
X = X.loc[:, (X != 0).any(axis=0)]  # Removing columns with all zeros
X = X.dropna(axis=1, how='all')  # Removing columns with all NaNs
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
# fitting NaN values WITH MEAN
imputer = SimpleImputer(strategy='mean')
X_train = X_train.dropna(axis=1, how='all')
X_test = X_test[X_train.columns]
# Fitting the imputer on your training data and transforming it
X_train_imputed = imputer.fit_transform(X_train)
# Transforming test data using the trained imputer
X_test_imputed = imputer.transform(X_test)
dbscan = DBSCAN(eps=0.5, min_samples=5)
labels_train = dbscan.fit_predict(X_train_imputed)
labels_test = dbscan.fit_predict(X_test_imputed)

# %%
labels_train = np.where(labels_train == -1, len(set(labels_train)), labels_train)
labels_test = np.where(labels_test == -1, len(set(labels_train)), labels_test)

# %%
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train_scaled, labels_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
#joblib.dump(rf_model, "random_forest_model.pkl")
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
y_pred = rf_model.predict(X_test_scaled)
print("Random Forest Classifier Evaluation:")
print(f"Accuracy: {accuracy_score(labels_test, y_pred):.3f}")
print(classification_report(labels_test, y_pred))
# Out:
# Random Forest Classifier Evaluation:
# Accuracy: 1.000
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       145
#
#     accuracy                           1.00       145
#    macro avg       1.00      1.00      1.00       145
# weighted avg       1.00      1.00      1.00       145
